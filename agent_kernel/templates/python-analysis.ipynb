# %% [markdown]
# # Python analysis template
#
# A placeholder analysis notebook.

# %%
# parameters
query = None
limit = 10

# %%
print(f"running with query={query!r} limit={limit}")

# %%
result = {"query": query, "limit": limit, "ok": True}
result
